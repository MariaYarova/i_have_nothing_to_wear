# %%
import pandas as pd

data = pd.read_csv('data.csv')

# %%
data
# Out:
#         name                                        description
# 0    sweater     red light sweater with a white image of a deer
# 1      shoes            blue summer strap sandals with sparkles
# 2     jacket   black leather jacket with silver zippers and ...
# 3      jeans        classic blue skinny jeans with ripped knees
# 4        hat   beige straw hat with a black ribbon around th...
# 5      scarf         long wool scarf in green and white stripes
# 6      shirt   white cotton shirt with short sleeves and a p...
# 7      skirt      pleated navy-blue skirt with a floral pattern
# 8     gloves    thick black winter gloves with touchscreen tips
# 9      boots   brown ankle boots with a low heel and buckle ...
# 10       tie   silk tie in a deep burgundy color with small ...
# 11      coat     oversized beige trench coat with large buttons
# 12     dress   sleeveless red cocktail dress with a bow at t...
# 13      belt       brown leather belt with a gold square buckle
# ...
